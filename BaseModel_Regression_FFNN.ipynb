# %%
#Import standard packages for model training

import tensorflow as T
from tensorflow import *
from tensorflow.keras import initializers
from tensorflow.keras import regularizers
from tensorflow.keras import layers
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.losses import *
import numpy as np
import pandas as pd
import sklearn.metrics as SK
from sklearn.metrics import *
import matplotlib.pyplot as plt
import seaborn as sns
import os 
import io
from utils.GPU import *
from utils import utils
commons = utils.Commons()
ts_helper = utils.TS_Helper()
ts_helper.model_type = ts_helper.Regression
shap_helper = utils.Shap_Helper()

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
# Out:
#   tensorlayer: GPU MEM Fraction 0.900000
# Num GPUs Available:  0

# %%
#Inport train, validation and test sets

training = './data/regression/Tb.rhodesiense/random_split/train_fold_4.csv'
validation = './data/regression/Tb.rhodesiense/random_split/valid_fold_4.csv'
test = './data/regression/Tb.rhodesiense/random_split/test_fold_4.csv'
SMILES = 'SMILES'
TASK_START = 2
NUM_TASKS = 1
train_dataset,y_train,train_smiles = commons.load_dataset(training,SMILES,TASK_START,NUM_TASKS)
valid_dataset,y_val,val_smiles = commons.load_dataset(validation,SMILES,TASK_START,NUM_TASKS)
test_dataset,y_test,test_smiles = commons.load_dataset(test,SMILES,TASK_START,NUM_TASKS)


train_dataset.head()
# Out:
# Loaded dataset ./data/regression/Tb.rhodesiense/random_split/train_fold_4.csv with shape: (1430, 3)
# Loaded dataset ./data/regression/Tb.rhodesiense/random_split/valid_fold_4.csv with shape: (179, 3)
# Loaded dataset ./data/regression/Tb.rhodesiense/random_split/test_fold_4.csv with shape: (179, 3)
#      ID                                             SMILES  Tb_rhodesiense
# 0  2357  O=C(C1C=CC(C2NCCN=2)=CC=1)NC1C=C(C(NC2C=CC(C3N...        6.920819
# 1   291  CC1C=C(Br)C(NC2N=C(NC3C=CC(C#N)=CC=3)N=C(C#N)N...        4.877129
# 2  2054  FC(OC1C(Cl)=CC(CC(C(NC2(C#N)CC2)=O)NC(C2C=NN(C...        9.000000
# 3  3455            CCCCCCCCCCCCCCCCC1(C(=O)C(CCC)=C(O)S1)C        4.537602
# 4  2313  CN(C12CC(C3C=CC=CC=3)C(C(C3C=CC=CC=3)C1)C(OC(C...        7.096910

# %%
# calculate ECFP (defaut) fingerprints using RDKit
FP_SIZE = 2048
RADIUS = 2
FEAT = False
X_train = commons.assing_fp(train_smiles,FP_SIZE,RADIUS,FEAT)
X_val = commons.assing_fp(val_smiles,FP_SIZE,RADIUS,FEAT)
X_test = commons.assing_fp(test_smiles,FP_SIZE,RADIUS,FEAT)

type(X_train), X_val.shape, X_test.shape
# Out:
# (numpy.ndarray, (179, 2048), (179, 2048))

# %%
#Parameters for train network

from utils.utils import *

bit_vector = X_train.shape[1]

def create_model():
    return T.keras.models.Sequential([
            T.keras.layers.Dense(15,input_dim=bit_vector, activation='relu'),
            T.keras.layers.Dropout(0.3),
            T.keras.layers.Dense(10, activation='relu'),
            T.keras.layers.Dropout(0.1),
            T.keras.layers.Dense(10, activation='relu'),
            T.keras.layers.Dropout(0.1),
            T.keras.layers.Dense(NUM_TASKS, activation='linear'),
            ])

       
optimizer = RMSprop(lr=0.001)
lr_metric = ts_helper.get_lr_metric(optimizer)
model = create_model()
model.compile(loss=ts_helper.regression_loss, metrics = [lr_metric])    
model.summary()
T.keras.utils.plot_model(model)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 15)                30735
#
#  dropout (Dropout)           (None, 15)                0
#
#  dense_1 (Dense)             (None, 10)                160
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense_2 (Dense)             (None, 10)                110
#
#  dropout_2 (Dropout)         (None, 10)                0
#
#  dense_3 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 31,016
# Trainable params: 31,016
# Non-trainable params: 0
# _________________________________________________________________
# c:\Users\Laplace\anaconda3\envs\AI\lib\site-packages\keras\optimizers\optimizer_v2\rmsprop.py:135: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(RMSprop, self).__init__(name, **kwargs)

# %%
# Early stopping parameters

callbacks_list = [
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=0.00000001, verbose=1, mode='auto',cooldown=0),
    ModelCheckpoint(filepath="./data/TM-FNN_regression_model.hdf5", monitor='val_loss', save_best_only=True, verbose=1, mode='auto'),
    EarlyStopping(monitor='val_loss', min_delta=0.001, patience=10, mode='min', verbose=1)
    ]


# parameters for train network

epochs=1000
batch_size=40

history = model.fit(X_train, y_train, 
                    epochs=epochs,
                    batch_size=batch_size,
                    validation_data=(X_val, y_val),
                    callbacks=(callbacks_list))
# Out:
# Epoch 1/1000
#  1/36 [..............................] - ETA: 23s - loss: 32.3897 - lr: 0.0010
# Epoch 1: val_loss improved from inf to 6.01888, saving model to ./data\TM-FNN_regression_model.hdf5
# 36/36 [==============================] - 1s 6ms/step - loss: 19.2732 - lr: 0.0010 - val_loss: 6.0189 - val_lr: 0.0010
# Epoch 2/1000
# 34/36 [===========================>..] - ETA: 0s - loss: 6.8652 - lr: 1.0000e-03
# Epoch 2: val_loss improved from 6.01888 to 2.43804, saving model to ./data\TM-FNN_regression_model.hdf5
# 36/36 [==============================] - 0s 3ms/step - loss: 6.7703 - lr: 0.0010 - val_loss: 2.4380 - val_lr: 0.0010
# Epoch 3/1000
# 35/36 [============================>.] - ETA: 0s - loss: 5.1430 - lr: 1.0000e-03
# Epoch 3: val_loss improved from 2.43804 to 1.91764, saving model to ./data\TM-FNN_regression_model.hdf5
# 36/36 [==============================] - 0s 3ms/step - loss: 5.1088 - lr: 0.0010 - val_loss: 1.9176 - val_lr: 0.0010
# Epoch 4/1000
#  1/36 [..............................] - ETA: 0s - loss: 3.0611 - lr: 0.0010
# Epoch 4: val_loss improved from 1.91764 to 1.65097, saving model to ./data\TM-FNN_regression_model.hdf5
# 36/36 [==============================] - 0s 3ms/step - loss: 4.4569 - lr: 0.0010 - val_loss: 1.6510 - val_lr: 0.0010
# Epoch 5/1000
# 33/36 [==========================>...] - ETA: 0s - loss: 3.9856 - lr: 0.0010
# Epoch 5: val_loss improved from 1.65097 to 1.43386, saving model to ./data\TM-FNN_regression_model.hdf5
# 36/36 [==============================] - 0s 3ms/step - loss: 3.9343 - lr: 0.0010 - val_loss: 1.4339 - val_lr: 0.0010
# Epoch 6/1000
#  1/36 [..............................] - ETA: 0s - loss: 2.8526 - lr: 0.0010
# Epoch 6: val_loss improved from 1.43386 to 1.13841, saving model to ./data\TM-FNN_regression_model.hdf5
# 36/36 [==============================] - 0s 2ms/step - loss: 3.5485 - lr: 0.0010 - val_loss: 1.1384 - val_lr: 0.0010
# Epoch 7/1000
#  1/36 [..............................] - ETA: 0s - loss: 2.5627 - lr: 0.0010
# Epoch 7: val_loss improved from 1.13841 to 1.00100, saving model to ./data\TM-FNN_regression_model.hdf5
# 36/36 [==============================] - 0s 2ms/step - loss: 3.2531 - lr: 0.0010 - val_loss: 1.0010 - val_lr: 0.0010
# Epoch 8/1000
#  1/36 [..............................] - ETA: 0s - loss: 2.6005 - lr: 0.0010
# Epoch 8: val_loss improved from 1.00100 to 0.88493, saving model to ./data\TM-FNN_regression_model.hdf5
# 36/36 [==============================] - 0s 2ms/step - loss: 3.0671 - lr: 0.0010 - val_loss: 0.8849 - val_lr: 0.0010
# Epoch 9/1000
#  1/36 [..............................] - ETA: 0s - loss: 2.4548 - lr: 0.0010
# Epoch 9: val_loss did not improve from 0.88493
# 36/36 [==============================] - 0s 2ms/step - loss: 2.8025 - lr: 0.0010 - val_loss: 0.8971 - val_lr: 0.0010
# Epoch 10/1000
#  1/36 [..............................] - ETA: 0s - loss: 2.6369 - lr: 0.0010
# Epoch 10: val_loss did not improve from 0.88493
# 36/36 [==============================] - 0s 2ms/step - loss: 2.5998 - lr: 0.0010 - val_loss: 1.4746 - val_lr: 0.0010
# Epoch 11/1000
#  1/36 [..............................] - ETA: 0s - loss: 2.2095 - lr: 0.0010
# Epoch 11: val_loss improved from 0.88493 to 0.85183, saving model to ./data\TM-FNN_regression_model.hdf5
# 36/36 [==============================] - 0s 3ms/step - loss: 2.4291 - lr: 0.0010 - val_loss: 0.8518 - val_lr: 0.0010
# Epoch 12/1000
# 36/36 [==============================] - ETA: 0s - loss: 2.2888 - lr: 1.0000e-03
# Epoch 12: val_loss did not improve from 0.85183
# 36/36 [==============================] - 0s 2ms/step - loss: 2.2888 - lr: 0.0010 - val_loss: 1.2107 - val_lr: 0.0010
# Epoch 13/1000
#  1/36 [..............................] - ETA: 0s - loss: 1.6653 - lr: 0.0010
# Epoch 13: val_loss did not improve from 0.85183
# 36/36 [==============================] - 0s 2ms/step - loss: 2.3903 - lr: 0.0010 - val_loss: 0.9941 - val_lr: 0.0010
# Epoch 14/1000
#  1/36 [..............................] - ETA: 0s - loss: 1.8364 - lr: 0.0010
# Epoch 14: val_loss improved from 0.85183 to 0.66108, saving model to ./data\TM-FNN_regression_model.hdf5
# 36/36 [==============================] - 0s 2ms/step - loss: 2.0573 - lr: 0.0010 - val_loss: 0.6611 - val_lr: 0.0010
# Epoch 15/1000
# 35/36 [============================>.] - ETA: 0s - loss: 1.9853 - lr: 1.0000e-03
# Epoch 15: val_loss did not improve from 0.66108
# 36/36 [==============================] - 0s 2ms/step - loss: 1.9691 - lr: 0.0010 - val_loss: 0.9406 - val_lr: 0.0010
# Epoch 16/1000
#  1/36 [..............................] - ETA: 0s - loss: 1.8715 - lr: 0.0010
# Epoch 16: val_loss did not improve from 0.66108
# 36/36 [==============================] - 0s 2ms/step - loss: 1.9578 - lr: 0.0010 - val_loss: 1.0231 - val_lr: 0.0010
# Epoch 17/1000
#  1/36 [..............................] - ETA: 0s - loss: 3.1476 - lr: 0.0010
# Epoch 17: val_loss did not improve from 0.66108
# 36/36 [==============================] - 0s 2ms/step - loss: 1.8972 - lr: 0.0010 - val_loss: 1.0036 - val_lr: 0.0010
# Epoch 18/1000
#  1/36 [..............................] - ETA: 0s - loss: 1.6274 - lr: 0.0010
# Epoch 18: val_loss improved from 0.66108 to 0.63955, saving model to ./data\TM-FNN_regression_model.hdf5
# 36/36 [==============================] - 0s 2ms/step - loss: 1.7092 - lr: 0.0010 - val_loss: 0.6395 - val_lr: 0.0010
# Epoch 19/1000
#  1/36 [..............................] - ETA: 0s - loss: 1.2270 - lr: 0.0010
# Epoch 19: val_loss improved from 0.63955 to 0.54757, saving model to ./data\TM-FNN_regression_model.hdf5
# 36/36 [==============================] - 0s 2ms/step - loss: 1.9228 - lr: 0.0010 - val_loss: 0.5476 - val_lr: 0.0010
# Epoch 20/1000
#  1/36 [..............................] - ETA: 0s - loss: 1.8228 - lr: 0.0010
# Epoch 20: val_loss did not improve from 0.54757
# 36/36 [==============================] - 0s 2ms/step - loss: 1.7819 - lr: 0.0010 - val_loss: 0.7623 - val_lr: 0.0010
# Epoch 21/1000
#  1/36 [..............................] - ETA: 0s - loss: 2.2823 - lr: 0.0010
# Epoch 21: val_loss did not improve from 0.54757
# 36/36 [==============================] - 0s 2ms/step - loss: 1.6287 - lr: 0.0010 - val_loss: 0.6014 - val_lr: 0.0010
# Epoch 22/1000
#  1/36 [..............................] - ETA: 0s - loss: 1.5460 - lr: 0.0010
# Epoch 22: val_loss did not improve from 0.54757
# 36/36 [==============================] - 0s 2ms/step - loss: 1.7059 - lr: 0.0010 - val_loss: 0.7646 - val_lr: 0.0010
# Epoch 23/1000
#  1/36 [..............................] - ETA: 0s - loss: 1.3500 - lr: 0.0010
# Epoch 23: val_loss did not improve from 0.54757
# 36/36 [==============================] - 0s 2ms/step - loss: 1.5797 - lr: 0.0010 - val_loss: 0.6787 - val_lr: 0.0010
# Epoch 24/1000
#  1/36 [..............................] - ETA: 0s - loss: 1.8465 - lr: 0.0010
# Epoch 24: val_loss did not improve from 0.54757
# 36/36 [==============================] - 0s 2ms/step - loss: 1.4219 - lr: 0.0010 - val_loss: 0.6632 - val_lr: 0.0010
# Epoch 25/1000
#  1/36 [..............................] - ETA: 0s - loss: 1.6174 - lr: 0.0010
# Epoch 25: val_loss did not improve from 0.54757
# 36/36 [==============================] - 0s 2ms/step - loss: 1.4254 - lr: 0.0010 - val_loss: 0.5586 - val_lr: 0.0010
# Epoch 26/1000
#  1/36 [..............................] - ETA: 0s - loss: 1.9578 - lr: 0.0010
# Epoch 26: val_loss did not improve from 0.54757
# 36/36 [==============================] - 0s 2ms/step - loss: 1.4693 - lr: 0.0010 - val_loss: 0.5677 - val_lr: 0.0010
# Epoch 27/1000
#  1/36 [..............................] - ETA: 0s - loss: 1.4423 - lr: 0.0010
# Epoch 27: val_loss did not improve from 0.54757
# 36/36 [==============================] - 0s 2ms/step - loss: 1.3115 - lr: 0.0010 - val_loss: 0.7332 - val_lr: 0.0010
# Epoch 28/1000
#  1/36 [..............................] - ETA: 0s - loss: 2.2623 - lr: 0.0010
# Epoch 28: val_loss did not improve from 0.54757
# 36/36 [==============================] - 0s 2ms/step - loss: 1.5224 - lr: 0.0010 - val_loss: 0.6066 - val_lr: 0.0010
# Epoch 29/1000
#  1/36 [..............................] - ETA: 0s - loss: 1.5053 - lr: 0.0010
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 29: val_loss did not improve from 0.54757
# 36/36 [==============================] - 0s 2ms/step - loss: 1.2865 - lr: 0.0010 - val_loss: 0.7368 - val_lr: 0.0010
# Epoch 29: early stopping

# %%
#Plot model history
ts_helper.plot_history(history)

# %%
#Statistical characteristico of model without 3-sigma rule
THRESHOLD = 0.5
#print(X_train.shape,y_train.shape)
#print(X_val.shape,y_val.shape)
#print(X_test.shape,y_test[:,0])

ts_helper.get_modelStatsFor_nSplits(model,NUM_TASKS,THRESHOLD,
X_train = X_train , y_train = y_train, 
X_test = X_test, y_test = y_test, 
X_val = X_val, y_val = y_val)
# Out:
# Metric for a Regression Model
# 45/45 [==============================] - 0s 659us/step
# Statistic       Value
# -----------  --------
# MSE          0.62959
# MAE          0.626331
# R2           0.631163
# 45/45 [==============================] - 0s 614us/step
# Metric for a Regression Model
# 6/6 [==============================] - 0s 1ms/step
# Statistic       Value
# -----------  --------
# MSE          0.654303
# MAE          0.627739
# R2           0.588101
# 6/6 [==============================] - 0s 1ms/step
# Metric for a Regression Model
# 6/6 [==============================] - 0s 1000us/step
# Statistic       Value
# -----------  --------
# MSE          0.736832
# MAE          0.694778
# R2           0.460283
# 6/6 [==============================] - 0s 1ms/step
